# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenThienPhat/NguyenThienPhat-24_02_2023/blob/main/ai_w9_31_03_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
(train_imgers,train_lables),(test_imgers,test_lables)=mnist.load_data()
X=test_imgers
Y=test_lables
train_imgers.shape
# Out:
# ...
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 28, 28)

# %%
train_lables.shape
test_imgers.shape
test_imgers.shape
# Out:
# (10000, 28, 28)

# %%
digit = train_imgers[99]
import matplotlib.pyplot as plt
plt.imshow(digit)
plt.show
print('so nay la',train_lables[99])
# Out:
# so nay la 1

# %%
digit = train_imgers[999]
import matplotlib.pyplot as plt
plt.imshow(digit)
plt.show
print('so nay la',train_lables[999])
# Out:
# so nay la 6

# %%
for i in range (10):
  plt.subplot(2,5,i+1)
  plt.tight_layout
  plt.imshow(train_imgers[i],cmap='gray',interpolation='None')
  plt.title('so nay la:{}'.format(train_lables[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range (20):
  plt.subplot(5,5,i+1)
  plt.tight_layout
  plt.imshow(train_imgers[i],cmap='Blues',interpolation='None')
  plt.title('so nay la:{}'.format(train_lables[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(28*28,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_imgers= train_imgers.reshape((60000,28*28))
train_imgers=train_imgers.astype('float32')/255
train_imgers.shape
# Out:
# (60000, 784)

# %%
test_imgers= test_imgers.reshape((10000,28*28))
test_imgers=test_imgers.astype('float32')/255
test_imgers.shape
# Out:
# (10000, 784)

# %%
from keras.utils import to_categorical
train_lables=to_categorical(train_lables,10)
test_lables=to_categorical(test_lables,10)
train_lables.shape
# Out:
# (60000, 10)

# %%
test_lables.shape
# Out:
# (10000, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_imgers,train_lables,epochs=20,batch_size=128)
test_loss,test_acc=model.evaluate(test_imgers,test_lables)
print('Do mat mat:',test_loss)
print('Do chinh xac:',test_acc)
# Out:
# Epoch 1/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.2663 - accuracy: 0.9234
# Epoch 2/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1087 - accuracy: 0.9683
# Epoch 3/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0713 - accuracy: 0.9785
# Epoch 4/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0518 - accuracy: 0.9843
# Epoch 5/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0390 - accuracy: 0.9886
# Epoch 6/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0294 - accuracy: 0.9911
# Epoch 7/20
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0221 - accuracy: 0.9936
# Epoch 8/20
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0169 - accuracy: 0.9952
# Epoch 9/20
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0127 - accuracy: 0.9968
# Epoch 10/20
# ...
