# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenThienPhat/NguyenThienPhat-24_02_2023/blob/main/bt_fuzzy_thienphat_20146388.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
sucgio= ctrl.Antecedent(np.arange(0.7,3.1,0.1),'sucgio')
nhietdo = ctrl.Antecedent(np.arange(20.4,41.2,0.1),'nhietdo')
luongmua = ctrl.Consequent(np.arange(0.2,9.1,0.1),'luongmua')

sucgio['ratyeu']=fuzz.trimf(sucgio.universe,[0.7,0.7,2.6])
sucgio['yeu']=fuzz.trimf(sucgio.universe,[0.7,2.6,3.05])
sucgio['tb']=fuzz.trimf(sucgio.universe,[2.6,3.0,3.05])
sucgio['manh']=fuzz.trimf(sucgio.universe,[3.0,3.05,3.1])
sucgio['ratmanh']=fuzz.trimf(sucgio.universe,[3.05,3.1,3.1])
nhietdo['ratthap']=fuzz.trimf(nhietdo.universe,[20.4,20.4,24.2])
nhietdo['thap']=fuzz.trimf(nhietdo.universe,[20.4,24.2,27.3])
nhietdo['tb']=fuzz.trimf(nhietdo.universe,[24.2,27.3,35.8])
nhietdo['cao']=fuzz.trimf(nhietdo.universe,[27.3,35.8,42.2])
nhietdo['ratcao']=fuzz.trimf(nhietdo.universe,[35.8,42.2,42.2])
luongmua['ratnho']=fuzz.trimf(luongmua.universe,[0.2,0.2,1.9])
luongmua['nho']=fuzz.trimf(luongmua.universe,[0.2,1.9,3.5])
luongmua['tb']=fuzz.trimf(luongmua.universe,[1.9,3.5,6.8])
luongmua['bu']=fuzz.trimf(luongmua.universe,[3.5,6.8,9.1])
luongmua['ratbu']=fuzz.trimf(luongmua.universe,[6.8,9.1,9.1])

luat1 = ctrl.Rule(sucgio['ratyeu'] & nhietdo['ratthap'],luongmua['ratnho'])
luat2 = ctrl.Rule(sucgio['ratyeu'] & nhietdo['thap'],luongmua['ratnho'])
luat3 = ctrl.Rule(sucgio['ratyeu'] & nhietdo['tb'],luongmua['ratnho'])
luat4 = ctrl.Rule(sucgio['ratyeu'] & nhietdo['cao'],luongmua['nho'])
luat5 = ctrl.Rule(sucgio['ratyeu'] & nhietdo['ratcao'],luongmua['nho'])
luat6 = ctrl.Rule(sucgio['yeu'] & nhietdo['ratthap'],luongmua['ratnho'])
luat7 = ctrl.Rule(sucgio['yeu'] & nhietdo['thap'],luongmua['ratnho'])
luat8 = ctrl.Rule(sucgio['yeu'] & nhietdo['tb'],luongmua['nho'])
luat9 = ctrl.Rule(sucgio['yeu'] & nhietdo['cao'],luongmua['nho'])
luat10 = ctrl.Rule(sucgio['yeu'] & nhietdo['ratcao'],luongmua['nho'])
luat11 = ctrl.Rule(sucgio['tb'] & nhietdo['ratthap'],luongmua['ratnho'])
luat12= ctrl.Rule(sucgio['tb'] & nhietdo['thap'],luongmua['nho'])
luat13= ctrl.Rule(sucgio['tb'] & nhietdo['tb'],luongmua['nho'])
luat14 = ctrl.Rule(sucgio['tb'] & nhietdo['cao'],luongmua['tb'])
luat15 = ctrl.Rule(sucgio['tb'] & nhietdo['ratcao'],luongmua['tb'])
luat16 = ctrl.Rule(sucgio['manh'] & nhietdo['ratthap'],luongmua['nho'])
luat17 = ctrl.Rule(sucgio['manh'] & nhietdo['thap'],luongmua['nho'])
luat18 = ctrl.Rule(sucgio['manh'] & nhietdo['tb'],luongmua['tb'])
luat19= ctrl.Rule(sucgio['manh'] & nhietdo['cao'],luongmua['bu'])
luat20 = ctrl.Rule(sucgio['manh'] & nhietdo['ratcao'],luongmua['bu'])
luat21 = ctrl.Rule(sucgio['ratmanh'] & nhietdo['ratthap'],luongmua['tb'])
luat22 = ctrl.Rule(sucgio['ratmanh'] & nhietdo['thap'],luongmua['tb'])
luat23 = ctrl.Rule(sucgio['ratmanh'] & nhietdo['tb'],luongmua['bu'])
luat24 = ctrl.Rule(sucgio['ratmanh'] & nhietdo['cao'],luongmua['ratbu'])
luat25 = ctrl.Rule(sucgio['ratmanh'] & nhietdo['ratcao'],luongmua['ratbu'])

tipping_ctrl = ctrl.ControlSystem([luat1,luat2,luat3,luat4,luat5,luat6,luat7,luat8,luat9,luat10,luat11,luat12,luat13,luat14,luat15,luat16,luat17,luat18,luat19,luat20,luat21,luat22,luat23,luat24,luat25])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['sucgio']=2.77
tipping.input['nhietdo']=34
tipping.compute()
print(tipping.output['luongmua'])
luongmua.view(sim = tipping)
# Out:
# 3.1702701373204922

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
Mvi= ctrl.Antecedent(np.arange(1,3,0.1),'Mvi')
Mtruong = ctrl.Antecedent(np.arange(1,3,0.1),'Mtruong')
Nsach = ctrl.Antecedent(np.arange(1,3,0.1),'Nsach')
Dgia= ctrl.Antecedent(np.arange(1,3,0.1),'Dgia')
Vtri = ctrl.Antecedent(np.arange(1,3,0.1),'Vtri')
capdo = ctrl.Consequent(np.arange(0,15,0.1),'capdo')

Mvi['do']=fuzz.trimf(Mvi.universe,[1,1,2])
Mvi['bth']=fuzz.trimf(Mvi.universe,[1,2,3])
Mvi['ngon']=fuzz.trimf(Mvi.universe,[2,3,3])
Mtruong['do']=fuzz.trimf(Mtruong.universe,[1,1,2])
Mtruong['bth']=fuzz.trimf(Mtruong.universe,[1,2,3])
Mtruong['ngon']=fuzz.trimf(Mtruong.universe,[2,3,3])
Nsach['do']=fuzz.trimf(Nsach.universe,[1,1,2])
Nsach['bth']=fuzz.trimf(Nsach.universe,[1,2,3])
Nsach['ngon']=fuzz.trimf(Nsach.universe,[2,3,3])
Dgia['do']=fuzz.trimf(Dgia.universe,[1,1,2])
Dgia['bth']=fuzz.trimf(Dgia.universe,[1,2,3])
Dgia['ngon']=fuzz.trimf(Dgia.universe,[2,3,3])
Vtri['do']=fuzz.trimf(Vtri.universe,[1,1,2])
Vtri['bth']=fuzz.trimf(Vtri.universe,[1,2,3])
Vtri['ngon']=fuzz.trimf(Vtri.universe,[2,3,3])
capdo['1']=fuzz.trimf(capdo.universe,[0,0,3])
capdo['2']=fuzz.trimf(capdo.universe,[3,3,6])
capdo['3']=fuzz.trimf(capdo.universe,[3,6,12])
capdo['4']=fuzz.trimf(capdo.universe,[6,12,15])
capdo['5']=fuzz.trimf(capdo.universe,[12,15,15])

luat1 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['do'] & Vtri['do'],capdo['2'])
luat2 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['do'] & Vtri['bth'],capdo['2'])
luat3 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['do'] & Vtri['ngon'],capdo['3'])
luat4 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['bth'] & Vtri['do'],capdo['2'])
luat5 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['bth'] & Vtri['bth'],capdo['3'])
luat6 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['3'])
luat7 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['ngon'] & Vtri['do'],capdo['3'])
luat8 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['ngon'] & Vtri['bth'],capdo['3'])
luat9 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['do'] & Dgia['ngon'] & Vtri['ngon'],capdo['3'])
luat10 = ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['do'] & Vtri['do'],capdo['2'])
luat11= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['do'] & Vtri['bth'],capdo['3'])
luat12= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['do'] & Vtri['ngon'],capdo['3'])
luat13= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['bth'] & Vtri['do'],capdo['3'])
luat14= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['bth'] & Vtri['bth'],capdo['3'])
luat15= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['bth'] & Vtri['ngon'],capdo['3'])
luat16= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['ngon'] & Vtri['do'],capdo['3'])
luat17= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['ngon'] & Vtri['bth'],capdo['3'])
luat18= ctrl.Rule(Mvi['do'] & Mtruong['do'] & Nsach['bth'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat19= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['do'] & Vtri['do'],capdo['3'])
luat20= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['do'] & Vtri['bth'],capdo['3'])
luat21= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['do'] & Vtri['ngon'],capdo['4'])
luat22= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['bth'] & Vtri['do'],capdo['3'])
luat23= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['bth'] & Vtri['bth'],capdo['4'])
luat24= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat25= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['do'],capdo['4'])
luat26= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['bth'],capdo['4'])
luat27= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat28= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['do'] & Vtri['do'],capdo['2'])
luat29= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['do'] & Vtri['bth'],capdo['3'])
luat30= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['do'] & Vtri['ngon'],capdo['3'])
luat31= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['bth'] & Vtri['do'],capdo['3'])
luat32= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['bth'] & Vtri['bth'],capdo['3'])
luat33= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['3'])
luat34= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['ngon'] & Vtri['do'],capdo['3'])
luat35= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['ngon'] & Vtri['bth'],capdo['3'])
luat36= ctrl.Rule(Mvi['do'] & Mtruong['bth'] & Nsach['do'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat37= ctrl.Rule(Mvi['ngon'] & Mtruong['do'] & Nsach['do'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat38= ctrl.Rule(Mvi['ngon'] & Mtruong['bth'] & Nsach['do'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat39= ctrl.Rule(Mvi['ngon'] & Mtruong['ngon'] & Nsach['bth'] & Dgia['ngon'] & Vtri['ngon'],capdo['5'])
luat40= ctrl.Rule(Mvi['ngon'] & Mtruong['do'] & Nsach['bth'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat41= ctrl.Rule(Mvi['ngon'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['bth'] & Vtri['ngon'],capdo['5'])
luat42= ctrl.Rule(Mvi['ngon'] & Mtruong['ngon'] & Nsach['ngon'] & Dgia['bth'] & Vtri['ngon'],capdo['5'])
luat43= ctrl.Rule(Mvi['ngon'] & Mtruong['do'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat44= ctrl.Rule(Mvi['ngon'] & Mtruong['bth'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat45= ctrl.Rule(Mvi['ngon'] & Mtruong['ngon'] & Nsach['bth'] & Dgia['do'] & Vtri['ngon'],capdo['4'])
luat46= ctrl.Rule(Mvi['bth'] & Mtruong['do'] & Nsach['bth'] & Dgia['do'] & Vtri['ngon'],capdo['3'])
luat48= ctrl.Rule(Mvi['bth'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['do'] & Vtri['ngon'],capdo['4'])
luat49= ctrl.Rule(Mvi['bth'] & Mtruong['ngon'] & Nsach['ngon'] & Dgia['do'] & Vtri['ngon'],capdo['4'])
luat50= ctrl.Rule(Mvi['bth'] & Mtruong['do'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['3'])
luat51= ctrl.Rule(Mvi['bth'] & Mtruong['bth'] & Nsach['do'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat52= ctrl.Rule(Mvi['bth'] & Mtruong['ngon'] & Nsach['bth'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat53= ctrl.Rule(Mvi['bth'] & Mtruong['do'] & Nsach['bth'] & Dgia['bth'] & Vtri['ngon'],capdo['4'])
luat54= ctrl.Rule(Mvi['bth'] & Mtruong['bth'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['ngon'],capdo['5'])
luat55= ctrl.Rule(Mvi['bth'] & Mtruong['ngon'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['ngon'],capdo['5'])
luat56= ctrl.Rule(Mvi['bth'] & Mtruong['do'] & Nsach['do'] & Dgia['ngon'] & Vtri['ngon'],capdo['4'])
luat57= ctrl.Rule(Mvi['bth'] & Mtruong['bth'] & Nsach['bth'] & Dgia['ngon'] & Vtri['ngon'],capdo['5'])
luat47= ctrl.Rule(Mvi['ngon'] & Mtruong['ngon'] & Nsach['ngon'] & Dgia['ngon'] & Vtri['ngon'],capdo['5'])

tipping_ctrl = ctrl.ControlSystem([luat1,luat2,luat3,luat4,luat5,luat6,luat7,luat8,luat9,luat10,luat11,luat12,luat13,luat14,luat15,luat16,luat17,luat18,luat19,luat20,luat21,luat22,luat23,luat24,luat25,luat26,luat27,luat28,luat29,luat30,luat31,luat32,luat33,luat34,luat35,luat36,luat37,luat38,luat39,luat40,luat41,luat42,luat43,luat44,luat45,luat46,luat48,luat49,luat50,luat51,luat52,luat53,luat54,luat55,luat56,luat57,luat47])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['Mvi']=1.5
tipping.input['Mtruong']=2
tipping.input['Nsach']=1.5
tipping.input['Dgia']=1.2
tipping.input['Vtri']=2
tipping.compute()
print(tipping.output['capdo'])
capdo.view(sim = tipping)
# Out:
# 7.166666666666668
