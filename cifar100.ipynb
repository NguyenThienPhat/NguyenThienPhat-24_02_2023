# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenThienPhat/NguyenThienPhat-24_02_2023/blob/main/cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
(X_train,Y_train),(X_test,Y_test) =cifar100.load_data()
print(X_train.shape)
print(Y_train.shape)
# Out:
# ...
# 169001437/169001437 [==============================] - 4s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (10000, 32, 32, 3)
# (10000, 1)

# %%
digit = X_train[1610]
import matplotlib.pyplot as plt
plt.imshow(digit)
plt.show
print('so nay la',Y_train[1610])
# Out:
# so nay la [49]

# %%
for i in range (15):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(X_train[i],cmap='gray',interpolation='None')
  plt.title('dayla:{}'.format(Y_train[i+1610]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(5000,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(5000,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(5000,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5000)              15365000
#
#  dense_1 (Dense)             (None, 5000)              25005000
#
#  dense_2 (Dense)             (None, 5000)              25005000
#
#  dense_3 (Dense)             (None, 100)               500100
#
# ...
# Total params: 65,875,100
# Trainable params: 65,875,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train= X_train.reshape((50000,32*32*3))
X_train=X_train.astype('float32')/255
print(X_train.shape)
# Out:
# (50000, 3072)

# %%
X_test= X_test.reshape((10000,32*32*3))
X_test=X_test.astype('float32')/255
print(X_test.shape)
# Out:
# (10000, 3072)

# %%
from keras.utils import to_categorical
Y_train=to_categorical(Y_train,100)
Y_test=to_categorical(Y_test,100)
print(Y_train.shape)
# Out:
# (50000, 100)

# %%
print(Y_test.shape)
# Out:
# (10000, 100)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(X_test,Y_test)
print('Do mat mat:',test_loss)
print('Do chinh xac:',test_acc)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 851s 2s/step - loss: 4.4929 - accuracy: 0.0494
# Epoch 2/10
# 391/391 [==============================] - 863s 2s/step - loss: 3.8947 - accuracy: 0.0997
# Epoch 3/10
# 391/391 [==============================] - 851s 2s/step - loss: 3.6850 - accuracy: 0.1345
# Epoch 4/10
# 391/391 [==============================] - 854s 2s/step - loss: 3.5364 - accuracy: 0.1611
# Epoch 5/10
# 391/391 [==============================] - 866s 2s/step - loss: 3.4167 - accuracy: 0.1794
# Epoch 6/10
# 391/391 [==============================] - 884s 2s/step - loss: 3.3178 - accuracy: 0.1977
# Epoch 7/10
# 391/391 [==============================] - 885s 2s/step - loss: 3.2167 - accuracy: 0.2153
# Epoch 8/10
# 391/391 [==============================] - 877s 2s/step - loss: 3.1130 - accuracy: 0.2358
# Epoch 9/10
# 391/391 [==============================] - 877s 2s/step - loss: 3.0132 - accuracy: 0.2527
# Epoch 10/10
# ...

# %%
model.save('test.h5')

# %%
img=plt.imread('/content/con voi.jpg')
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img, img_to_array
img = load_img("/content/con voi.jpg", target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')
img = img/255
np.argmax(model.predict(img), axis = -1)
# Out:
# 1/1 [==============================] - 0s 119ms/step
# array([7])
